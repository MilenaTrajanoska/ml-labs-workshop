# %% [markdown]
# # Product Price Estimation

# %% [markdown]
# ## Read the data

# %%
import pandas as pd

# %%
data = pd.read_csv("data/products.csv")

# %%
data.head()
# Out:
#   Product ID Product Name   Price  Stock Quantity  Warranty Period  \
# 0   93TGNAY7       Laptop     NaN             3.0              2.0
# 1   TYYZ5AV7   Smartphone  214.37            92.0              2.0
# 2   5C94FGTQ   Headphones  475.29            19.0              2.0
# 3   XBHKYPQB      Monitor     NaN            40.0              1.0
# 4   728GCZFU       Laptop  229.81            32.0              2.0
#
#   Product Dimensions Manufacturing Date Expiration Date Color/Size Variations  \
# 0        16x15x15 cm         2023-01-01      2026-01-01           Green/Large
# 1        15x19x19 cm         2023-03-15      2025-01-01             Red/Small
# 2           9x6x6 cm         2023-03-15      2026-01-01             Red/Small
# 3          7x13x5 cm         2023-01-01      2026-01-01           Green/Large
# 4        20x20x19 cm         2023-07-30      2026-01-01           Blue/Medium
#
#    Product Ratings
# 0              NaN
# 1              2.0
# 2              NaN
# 3              NaN
# 4              4.0

# %%
data.describe()
# Out:
#              Price  Stock Quantity  Warranty Period  Product Ratings
# count  8500.000000     8605.000000      8800.000000      7638.000000
# mean    254.767901       50.595119         2.015000         3.025007
# std     143.028881       28.912863         0.819832         1.425383
# min      10.220000        1.000000         1.000000         1.000000
# 25%     129.855000       25.000000         1.000000         2.000000
# 50%     252.715000       50.000000         2.000000         3.000000
# 75%     380.837500       76.000000         3.000000         4.000000
# max     499.970000      100.000000         3.000000         5.000000

# %%
data.isnull().sum() / len(data) * 100
# Out:
# Product ID                0.00
# Product Name              0.00
# Price                    15.00
# Stock Quantity           13.95
# Warranty Period          12.00
# Product Dimensions        0.00
# Manufacturing Date        0.00
# Expiration Date           0.00
# Color/Size Variations     0.00
# Product Ratings          23.62
# dtype: float64

# %% [markdown]
# ## Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot(data['Price'], kde=True, bins=30)
plt.show()

# %%
data['Warranty Period'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Warranty Period'>

# %% [markdown]
# ## Handling Missing Values

# %%
import missingno as msno

# %%
msno.heatmap(data)
# Out:
# <Axes: >

# %%
data["Warranty Period"].median()
# Out:
# np.float64(2.0)

# %%
data["Warranty Period"] = data["Warranty Period"].fillna(data["Warranty Period"].median())

# %%
data.isnull().sum()
# Out:
# Product ID                  0
# Product Name                0
# Price                    1500
# Stock Quantity           1395
# Warranty Period             0
# Product Dimensions          0
# Manufacturing Date          0
# Expiration Date             0
# Color/Size Variations       0
# Product Ratings          2362
# dtype: int64

# %%
from sklearn.impute import KNNImputer

# %%
imputer = KNNImputer(n_neighbors=5)

# %%
data[["Price", "Stock Quantity", "Product Ratings"]]
# Out:
#        Price  Stock Quantity  Product Ratings
# 0        NaN             3.0              NaN
# 1     214.37            92.0              2.0
# 2     475.29            19.0              NaN
# 3        NaN            40.0              NaN
# 4     229.81            32.0              4.0
# ...      ...             ...              ...
# 9995   21.48            91.0              1.0
# 9996  403.92            19.0              4.0
# 9997  484.46             NaN              1.0
# 9998  411.63             NaN              NaN
# 9999   74.38            81.0              1.0
#
# [10000 rows x 3 columns]

# %%
data[["Price", "Stock Quantity", "Product Ratings"]] = imputer.fit_transform(data[["Price", "Stock Quantity", "Product Ratings"]])

# %%
data.isnull().sum()
# Out:
# Product ID               0
# Product Name             0
# Price                    0
# Stock Quantity           0
# Warranty Period          0
# Product Dimensions       0
# Manufacturing Date       0
# Expiration Date          0
# Color/Size Variations    0
# Product Ratings          0
# dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
data
# Out:
#      Product ID Product Name    Price  Stock Quantity  Warranty Period  \
# 0      93TGNAY7       Laptop  313.342             3.0              2.0
# 1      TYYZ5AV7   Smartphone  214.370            92.0              2.0
# 2      5C94FGTQ   Headphones  475.290            19.0              2.0
# 3      XBHKYPQB      Monitor  265.532            40.0              1.0
# 4      728GCZFU       Laptop  229.810            32.0              2.0
# ...         ...          ...      ...             ...              ...
# 9995   J29B6RDI   Headphones   21.480            91.0              3.0
# 9996   L1HL7437       Laptop  403.920            19.0              2.0
# 9997   FD57S4E1       Laptop  484.460            58.6              2.0
# 9998   RPYLOB1M   Headphones  411.630            58.8              1.0
# 9999   3JWTGTOM       Laptop   74.380            81.0              1.0
#
#      Product Dimensions Manufacturing Date Expiration Date  \
# 0           16x15x15 cm         2023-01-01      2026-01-01
# 1           15x19x19 cm         2023-03-15      2025-01-01
# 2              9x6x6 cm         2023-03-15      2026-01-01
# 3             7x13x5 cm         2023-01-01      2026-01-01
# 4           20x20x19 cm         2023-07-30      2026-01-01
# ...                 ...                ...             ...
# 9995         10x16x9 cm         2023-03-15      2026-01-01
# 9996          13x8x5 cm         2023-01-01      2024-01-01
# 9997         5x15x15 cm         2023-01-01      2024-01-01
# 9998        17x11x17 cm         2023-07-30      2026-01-01
# 9999          6x6x16 cm         2023-01-01      2025-01-01
#
#      Color/Size Variations  Product Ratings
# 0              Green/Large              3.2
# 1                Red/Small              2.0
# 2                Red/Small              2.4
# 3              Green/Large              2.6
# 4              Blue/Medium              4.0
# ...                    ...              ...
# 9995           Blue/Medium              1.0
# 9996             Red/Small              4.0
# 9997             Red/Small              1.0
# 9998             Red/Small              3.2
# 9999           Blue/Medium              1.0
#
# [10000 rows x 10 columns]

# %%
data = data.drop(columns=["Product ID"])

# %%
data
# Out:
#      Product Name    Price  Stock Quantity  Warranty Period  \
# 0          Laptop  313.342             3.0              2.0
# 1      Smartphone  214.370            92.0              2.0
# 2      Headphones  475.290            19.0              2.0
# 3         Monitor  265.532            40.0              1.0
# 4          Laptop  229.810            32.0              2.0
# ...           ...      ...             ...              ...
# 9995   Headphones   21.480            91.0              3.0
# 9996       Laptop  403.920            19.0              2.0
# 9997       Laptop  484.460            58.6              2.0
# 9998   Headphones  411.630            58.8              1.0
# 9999       Laptop   74.380            81.0              1.0
#
#      Product Dimensions Manufacturing Date Expiration Date  \
# 0           16x15x15 cm         2023-01-01      2026-01-01
# 1           15x19x19 cm         2023-03-15      2025-01-01
# 2              9x6x6 cm         2023-03-15      2026-01-01
# 3             7x13x5 cm         2023-01-01      2026-01-01
# 4           20x20x19 cm         2023-07-30      2026-01-01
# ...                 ...                ...             ...
# 9995         10x16x9 cm         2023-03-15      2026-01-01
# 9996          13x8x5 cm         2023-01-01      2024-01-01
# 9997         5x15x15 cm         2023-01-01      2024-01-01
# 9998        17x11x17 cm         2023-07-30      2026-01-01
# 9999          6x6x16 cm         2023-01-01      2025-01-01
#
#      Color/Size Variations  Product Ratings
# 0              Green/Large              3.2
# 1                Red/Small              2.0
# 2                Red/Small              2.4
# 3              Green/Large              2.6
# 4              Blue/Medium              4.0
# ...                    ...              ...
# 9995           Blue/Medium              1.0
# 9996             Red/Small              4.0
# 9997             Red/Small              1.0
# 9998             Red/Small              3.2
# 9999           Blue/Medium              1.0
#
# [10000 rows x 9 columns]

# %%
def extract_dimensions(dimension):
    dimension = dimension.replace(" cm", "")
    w, h, d = dimension.split("x")
    return w, h, d

# %%
widths = []
heights = []
depths = []

for dim in data["Product Dimensions"].values:
    w, h, d = extract_dimensions(dim)
    widths.append(int(w))
    heights.append(int(h))
    depths.append(int(d))

# %%
data["Width"] = widths
data["Heights"] = heights
data["Depth"] = depths

# %%
data
# Out:
#      Product Name    Price  Stock Quantity  Warranty Period  \
# 0          Laptop  313.342             3.0              2.0
# 1      Smartphone  214.370            92.0              2.0
# 2      Headphones  475.290            19.0              2.0
# 3         Monitor  265.532            40.0              1.0
# 4          Laptop  229.810            32.0              2.0
# ...           ...      ...             ...              ...
# 9995   Headphones   21.480            91.0              3.0
# 9996       Laptop  403.920            19.0              2.0
# 9997       Laptop  484.460            58.6              2.0
# 9998   Headphones  411.630            58.8              1.0
# 9999       Laptop   74.380            81.0              1.0
#
#      Product Dimensions Manufacturing Date Expiration Date  \
# 0           16x15x15 cm         2023-01-01      2026-01-01
# 1           15x19x19 cm         2023-03-15      2025-01-01
# 2              9x6x6 cm         2023-03-15      2026-01-01
# 3             7x13x5 cm         2023-01-01      2026-01-01
# 4           20x20x19 cm         2023-07-30      2026-01-01
# ...                 ...                ...             ...
# 9995         10x16x9 cm         2023-03-15      2026-01-01
# 9996          13x8x5 cm         2023-01-01      2024-01-01
# 9997         5x15x15 cm         2023-01-01      2024-01-01
# 9998        17x11x17 cm         2023-07-30      2026-01-01
# 9999          6x6x16 cm         2023-01-01      2025-01-01
#
#      Color/Size Variations  Product Ratings  Width  Heights  Depth
# 0              Green/Large              3.2     16       15     15
# 1                Red/Small              2.0     15       19     19
# 2                Red/Small              2.4      9        6      6
# 3              Green/Large              2.6      7       13      5
# 4              Blue/Medium              4.0     20       20     19
# ...                    ...              ...    ...      ...    ...
# 9995           Blue/Medium              1.0     10       16      9
# 9996             Red/Small              4.0     13        8      5
# 9997             Red/Small              1.0      5       15     15
# 9998             Red/Small              3.2     17       11     17
# 9999           Blue/Medium              1.0      6        6     16
#
# [10000 rows x 12 columns]

# %%
data = data.drop(columns=["Product Dimensions"])

# %%
data
# Out:
#      Product Name    Price  Stock Quantity  Warranty Period  \
# 0          Laptop  313.342             3.0              2.0
# 1      Smartphone  214.370            92.0              2.0
# 2      Headphones  475.290            19.0              2.0
# 3         Monitor  265.532            40.0              1.0
# 4          Laptop  229.810            32.0              2.0
# ...           ...      ...             ...              ...
# 9995   Headphones   21.480            91.0              3.0
# 9996       Laptop  403.920            19.0              2.0
# 9997       Laptop  484.460            58.6              2.0
# 9998   Headphones  411.630            58.8              1.0
# 9999       Laptop   74.380            81.0              1.0
#
#      Manufacturing Date Expiration Date Color/Size Variations  \
# 0            2023-01-01      2026-01-01           Green/Large
# 1            2023-03-15      2025-01-01             Red/Small
# 2            2023-03-15      2026-01-01             Red/Small
# 3            2023-01-01      2026-01-01           Green/Large
# 4            2023-07-30      2026-01-01           Blue/Medium
# ...                 ...             ...                   ...
# 9995         2023-03-15      2026-01-01           Blue/Medium
# 9996         2023-01-01      2024-01-01             Red/Small
# 9997         2023-01-01      2024-01-01             Red/Small
# 9998         2023-07-30      2026-01-01             Red/Small
# 9999         2023-01-01      2025-01-01           Blue/Medium
#
#       Product Ratings  Width  Heights  Depth
# 0                 3.2     16       15     15
# 1                 2.0     15       19     19
# 2                 2.4      9        6      6
# 3                 2.6      7       13      5
# 4                 4.0     20       20     19
# ...               ...    ...      ...    ...
# 9995              1.0     10       16      9
# 9996              4.0     13        8      5
# 9997              1.0      5       15     15
# 9998              3.2     17       11     17
# 9999              1.0      6        6     16
#
# [10000 rows x 11 columns]

# %%
data["Volume"] = data["Width"] * data["Heights"] * data["Depth"]

# %%
data
# Out:
#      Product Name    Price  Stock Quantity  Warranty Period  \
# 0          Laptop  313.342             3.0              2.0
# 1      Smartphone  214.370            92.0              2.0
# 2      Headphones  475.290            19.0              2.0
# 3         Monitor  265.532            40.0              1.0
# 4          Laptop  229.810            32.0              2.0
# ...           ...      ...             ...              ...
# 9995   Headphones   21.480            91.0              3.0
# 9996       Laptop  403.920            19.0              2.0
# 9997       Laptop  484.460            58.6              2.0
# 9998   Headphones  411.630            58.8              1.0
# 9999       Laptop   74.380            81.0              1.0
#
#      Manufacturing Date Expiration Date Color/Size Variations  \
# 0            2023-01-01      2026-01-01           Green/Large
# 1            2023-03-15      2025-01-01             Red/Small
# 2            2023-03-15      2026-01-01             Red/Small
# 3            2023-01-01      2026-01-01           Green/Large
# 4            2023-07-30      2026-01-01           Blue/Medium
# ...                 ...             ...                   ...
# 9995         2023-03-15      2026-01-01           Blue/Medium
# 9996         2023-01-01      2024-01-01             Red/Small
# 9997         2023-01-01      2024-01-01             Red/Small
# 9998         2023-07-30      2026-01-01             Red/Small
# 9999         2023-01-01      2025-01-01           Blue/Medium
#
#       Product Ratings  Width  Heights  Depth  Volume
# 0                 3.2     16       15     15    3600
# 1                 2.0     15       19     19    5415
# 2                 2.4      9        6      6     324
# 3                 2.6      7       13      5     455
# 4                 4.0     20       20     19    7600
# ...               ...    ...      ...    ...     ...
# 9995              1.0     10       16      9    1440
# 9996              4.0     13        8      5     520
# 9997              1.0      5       15     15    1125
# 9998              3.2     17       11     17    3179
# 9999              1.0      6        6     16     576
#
# [10000 rows x 12 columns]

# %%
data[["Color", "Size"]] =data["Color/Size Variations"].str.split("/", expand=True)

# %%
data
# Out:
#      Product Name    Price  Stock Quantity  Warranty Period  \
# 0          Laptop  313.342             3.0              2.0
# 1      Smartphone  214.370            92.0              2.0
# 2      Headphones  475.290            19.0              2.0
# 3         Monitor  265.532            40.0              1.0
# 4          Laptop  229.810            32.0              2.0
# ...           ...      ...             ...              ...
# 9995   Headphones   21.480            91.0              3.0
# 9996       Laptop  403.920            19.0              2.0
# 9997       Laptop  484.460            58.6              2.0
# 9998   Headphones  411.630            58.8              1.0
# 9999       Laptop   74.380            81.0              1.0
#
#      Manufacturing Date Expiration Date Color/Size Variations  \
# 0            2023-01-01      2026-01-01           Green/Large
# 1            2023-03-15      2025-01-01             Red/Small
# 2            2023-03-15      2026-01-01             Red/Small
# 3            2023-01-01      2026-01-01           Green/Large
# 4            2023-07-30      2026-01-01           Blue/Medium
# ...                 ...             ...                   ...
# 9995         2023-03-15      2026-01-01           Blue/Medium
# 9996         2023-01-01      2024-01-01             Red/Small
# 9997         2023-01-01      2024-01-01             Red/Small
# 9998         2023-07-30      2026-01-01             Red/Small
# 9999         2023-01-01      2025-01-01           Blue/Medium
#
#       Product Ratings  Width  Heights  Depth  Volume  Color    Size
# 0                 3.2     16       15     15    3600  Green   Large
# 1                 2.0     15       19     19    5415    Red   Small
# 2                 2.4      9        6      6     324    Red   Small
# 3                 2.6      7       13      5     455  Green   Large
# 4                 4.0     20       20     19    7600   Blue  Medium
# ...               ...    ...      ...    ...     ...    ...     ...
# 9995              1.0     10       16      9    1440   Blue  Medium
# 9996              4.0     13        8      5     520    Red   Small
# 9997              1.0      5       15     15    1125    Red   Small
# 9998              3.2     17       11     17    3179    Red   Small
# 9999              1.0      6        6     16     576   Blue  Medium
#
# [10000 rows x 14 columns]

# %%
data = data.drop(columns=["Color/Size Variations"])

# %%
data
# Out:
#      Product Name    Price  Stock Quantity  Warranty Period  \
# 0          Laptop  313.342             3.0              2.0
# 1      Smartphone  214.370            92.0              2.0
# 2      Headphones  475.290            19.0              2.0
# 3         Monitor  265.532            40.0              1.0
# 4          Laptop  229.810            32.0              2.0
# ...           ...      ...             ...              ...
# 9995   Headphones   21.480            91.0              3.0
# 9996       Laptop  403.920            19.0              2.0
# 9997       Laptop  484.460            58.6              2.0
# 9998   Headphones  411.630            58.8              1.0
# 9999       Laptop   74.380            81.0              1.0
#
#      Manufacturing Date Expiration Date  Product Ratings  Width  Heights  \
# 0            2023-01-01      2026-01-01              3.2     16       15
# 1            2023-03-15      2025-01-01              2.0     15       19
# 2            2023-03-15      2026-01-01              2.4      9        6
# 3            2023-01-01      2026-01-01              2.6      7       13
# 4            2023-07-30      2026-01-01              4.0     20       20
# ...                 ...             ...              ...    ...      ...
# 9995         2023-03-15      2026-01-01              1.0     10       16
# 9996         2023-01-01      2024-01-01              4.0     13        8
# 9997         2023-01-01      2024-01-01              1.0      5       15
# 9998         2023-07-30      2026-01-01              3.2     17       11
# 9999         2023-01-01      2025-01-01              1.0      6        6
#
#       Depth  Volume  Color    Size
# 0        15    3600  Green   Large
# 1        19    5415    Red   Small
# 2         6     324    Red   Small
# 3         5     455  Green   Large
# 4        19    7600   Blue  Medium
# ...     ...     ...    ...     ...
# 9995      9    1440   Blue  Medium
# 9996      5     520    Red   Small
# 9997     15    1125    Red   Small
# 9998     17    3179    Red   Small
# 9999     16     576   Blue  Medium
#
# [10000 rows x 13 columns]

# %%
data.Size.value_counts()
# Out:
# Size
# Small     3353
# Medium    3351
# Large     3296
# Name: count, dtype: int64

# %%
one_hot_colors = pd.get_dummies(data.Color, dtype=int)

# %%
data = pd.concat([data, one_hot_colors], axis=1)

# %%
data = data.drop(columns=["Color"])

# %%
data
# Out:
#      Product Name    Price  Stock Quantity  Warranty Period  \
# 0          Laptop  313.342             3.0              2.0
# 1      Smartphone  214.370            92.0              2.0
# 2      Headphones  475.290            19.0              2.0
# 3         Monitor  265.532            40.0              1.0
# 4          Laptop  229.810            32.0              2.0
# ...           ...      ...             ...              ...
# 9995   Headphones   21.480            91.0              3.0
# 9996       Laptop  403.920            19.0              2.0
# 9997       Laptop  484.460            58.6              2.0
# 9998   Headphones  411.630            58.8              1.0
# 9999       Laptop   74.380            81.0              1.0
#
#      Manufacturing Date Expiration Date  Product Ratings  Width  Heights  \
# 0            2023-01-01      2026-01-01              3.2     16       15
# 1            2023-03-15      2025-01-01              2.0     15       19
# 2            2023-03-15      2026-01-01              2.4      9        6
# 3            2023-01-01      2026-01-01              2.6      7       13
# 4            2023-07-30      2026-01-01              4.0     20       20
# ...                 ...             ...              ...    ...      ...
# 9995         2023-03-15      2026-01-01              1.0     10       16
# 9996         2023-01-01      2024-01-01              4.0     13        8
# 9997         2023-01-01      2024-01-01              1.0      5       15
# 9998         2023-07-30      2026-01-01              3.2     17       11
# 9999         2023-01-01      2025-01-01              1.0      6        6
#
#       Depth  Volume    Size  Blue  Green  Red
# 0        15    3600   Large     0      1    0
# 1        19    5415   Small     0      0    1
# 2         6     324   Small     0      0    1
# 3         5     455   Large     0      1    0
# 4        19    7600  Medium     1      0    0
# ...     ...     ...     ...   ...    ...  ...
# 9995      9    1440  Medium     1      0    0
# 9996      5     520   Small     0      0    1
# 9997     15    1125   Small     0      0    1
# 9998     17    3179   Small     0      0    1
# 9999     16     576  Medium     1      0    0
#
# [10000 rows x 15 columns]

# %%
def encode_size(size):
    if size == "Small":
        return 0
    if size == "Medium":
        return 1
    else:
        return 2

# %%
data["Size"] = data["Size"].apply(encode_size)

# %%
data["Manufacturing Date"] = pd.to_datetime(data["Manufacturing Date"])
data["Expiration Date"] = pd.to_datetime(data["Expiration Date"])

# %%
data["Manufacturing Year"] = data["Manufacturing Date"].dt.year
data["Expiration Year"] = data["Expiration Date"].dt.year

# %%
data["Years Valid"] = data["Expiration Year"] - data["Manufacturing Year"]

# %%
data = data.drop(columns=["Manufacturing Date", "Expiration Date"])

# %%
data["Product Name"].value_counts()
# Out:
# Product Name
# Headphones    2533
# Smartphone    2531
# Monitor       2469
# Laptop        2467
# Name: count, dtype: int64

# %%
one_hot_products = pd.get_dummies(data["Product Name"], dtype=int)

# %%
data = pd.concat([data, one_hot_products], axis=1)

# %%
data
# Out:
#      Product Name    Price  Stock Quantity  Warranty Period  Product Ratings  \
# 0          Laptop  313.342             3.0              2.0              3.2
# 1      Smartphone  214.370            92.0              2.0              2.0
# 2      Headphones  475.290            19.0              2.0              2.4
# 3         Monitor  265.532            40.0              1.0              2.6
# 4          Laptop  229.810            32.0              2.0              4.0
# ...           ...      ...             ...              ...              ...
# 9995   Headphones   21.480            91.0              3.0              1.0
# 9996       Laptop  403.920            19.0              2.0              4.0
# 9997       Laptop  484.460            58.6              2.0              1.0
# 9998   Headphones  411.630            58.8              1.0              3.2
# 9999       Laptop   74.380            81.0              1.0              1.0
#
#       Width  Heights  Depth  Volume  Size  Blue  Green  Red  \
# 0        16       15     15    3600     2     0      1    0
# 1        15       19     19    5415     0     0      0    1
# 2         9        6      6     324     0     0      0    1
# 3         7       13      5     455     2     0      1    0
# 4        20       20     19    7600     1     1      0    0
# ...     ...      ...    ...     ...   ...   ...    ...  ...
# 9995     10       16      9    1440     1     1      0    0
# 9996     13        8      5     520     0     0      0    1
# 9997      5       15     15    1125     0     0      0    1
# 9998     17       11     17    3179     0     0      0    1
# 9999      6        6     16     576     1     1      0    0
#
#       Manufacturing Year  Expiration Year  Years Valid  Headphones  Laptop  \
# 0                   2023             2026            3           0       1
# 1                   2023             2025            2           0       0
# 2                   2023             2026            3           1       0
# 3                   2023             2026            3           0       0
# 4                   2023             2026            3           0       1
# ...                  ...              ...          ...         ...     ...
# 9995                2023             2026            3           1       0
# 9996                2023             2024            1           0       1
# 9997                2023             2024            1           0       1
# 9998                2023             2026            3           1       0
# 9999                2023             2025            2           0       1
#
#       Monitor  Smartphone
# 0           0           0
# 1           0           1
# 2           0           0
# 3           1           0
# 4           0           0
# ...       ...         ...
# 9995        0           0
# 9996        0           0
# 9997        0           0
# 9998        0           0
# 9999        0           0
#
# [10000 rows x 20 columns]

# %%
data = data.drop(columns=["Product Name"])

# %%
data
# Out:
#         Price  Stock Quantity  Warranty Period  Product Ratings  Width  \
# 0     313.342             3.0              2.0              3.2     16
# 1     214.370            92.0              2.0              2.0     15
# 2     475.290            19.0              2.0              2.4      9
# 3     265.532            40.0              1.0              2.6      7
# 4     229.810            32.0              2.0              4.0     20
# ...       ...             ...              ...              ...    ...
# 9995   21.480            91.0              3.0              1.0     10
# 9996  403.920            19.0              2.0              4.0     13
# 9997  484.460            58.6              2.0              1.0      5
# 9998  411.630            58.8              1.0              3.2     17
# 9999   74.380            81.0              1.0              1.0      6
#
#       Heights  Depth  Volume  Size  Blue  Green  Red  Manufacturing Year  \
# 0          15     15    3600     2     0      1    0                2023
# 1          19     19    5415     0     0      0    1                2023
# 2           6      6     324     0     0      0    1                2023
# 3          13      5     455     2     0      1    0                2023
# 4          20     19    7600     1     1      0    0                2023
# ...       ...    ...     ...   ...   ...    ...  ...                 ...
# 9995       16      9    1440     1     1      0    0                2023
# 9996        8      5     520     0     0      0    1                2023
# 9997       15     15    1125     0     0      0    1                2023
# 9998       11     17    3179     0     0      0    1                2023
# 9999        6     16     576     1     1      0    0                2023
#
#       Expiration Year  Years Valid  Headphones  Laptop  Monitor  Smartphone
# 0                2026            3           0       1        0           0
# 1                2025            2           0       0        0           1
# 2                2026            3           1       0        0           0
# 3                2026            3           0       0        1           0
# 4                2026            3           0       1        0           0
# ...               ...          ...         ...     ...      ...         ...
# 9995             2026            3           1       0        0           0
# 9996             2024            1           0       1        0           0
# 9997             2024            1           0       1        0           0
# 9998             2026            3           1       0        0           0
# 9999             2025            2           0       1        0           0
#
# [10000 rows x 19 columns]

# %% [markdown]
# # Classification Modeling

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
X, Y = data.drop(columns=["Laptop", "Monitor", "Smartphone","Headphones"]), data["Laptop"]

# %%
X
# Out:
#         Price  Stock Quantity  Warranty Period  Product Ratings  Width  \
# 0     313.342             3.0              2.0              3.2     16
# 1     214.370            92.0              2.0              2.0     15
# 2     475.290            19.0              2.0              2.4      9
# 3     265.532            40.0              1.0              2.6      7
# 4     229.810            32.0              2.0              4.0     20
# ...       ...             ...              ...              ...    ...
# 9995   21.480            91.0              3.0              1.0     10
# 9996  403.920            19.0              2.0              4.0     13
# 9997  484.460            58.6              2.0              1.0      5
# 9998  411.630            58.8              1.0              3.2     17
# 9999   74.380            81.0              1.0              1.0      6
#
#       Heights  Depth  Volume  Size  Blue  Green  Red  Manufacturing Year  \
# 0          15     15    3600     2     0      1    0                2023
# 1          19     19    5415     0     0      0    1                2023
# 2           6      6     324     0     0      0    1                2023
# 3          13      5     455     2     0      1    0                2023
# 4          20     19    7600     1     1      0    0                2023
# ...       ...    ...     ...   ...   ...    ...  ...                 ...
# 9995       16      9    1440     1     1      0    0                2023
# 9996        8      5     520     0     0      0    1                2023
# 9997       15     15    1125     0     0      0    1                2023
# 9998       11     17    3179     0     0      0    1                2023
# 9999        6     16     576     1     1      0    0                2023
#
#       Expiration Year  Years Valid
# 0                2026            3
# 1                2025            2
# 2                2026            3
# 3                2026            3
# 4                2026            3
# ...               ...          ...
# 9995             2026            3
# 9996             2024            1
# 9997             2024            1
# 9998             2026            3
# 9999             2025            2
#
# [10000 rows x 15 columns]

# %%
Y
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 9995    0
# 9996    1
# 9997    1
# 9998    0
# 9999    1
# Name: Laptop, Length: 10000, dtype: int64

# %%
classifier = DecisionTreeClassifier(criterion="gini", max_depth=5)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y)

# %%
Y_train.value_counts()
# Out:
# Laptop
# 0    6026
# 1    1974
# Name: count, dtype: int64

# %%
classifier.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
Y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.99      0.86      1507
#            1       0.20      0.00      0.01       493
#
#     accuracy                           0.75      2000
#    macro avg       0.48      0.50      0.43      2000
# weighted avg       0.62      0.75      0.65      2000

# %%
import seaborn as sns

# %%
sns.heatmap(confusion_matrix(Y_test, Y_pred), annot=True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# ## Regression Modeling

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X, Y = data.drop(columns=["Price"]), data["Price"]

# %%
Y
# Out:
# 0       313.342
# 1       214.370
# 2       475.290
# 3       265.532
# 4       229.810
#          ...
# 9995     21.480
# 9996    403.920
# 9997    484.460
# 9998    411.630
# 9999     74.380
# Name: Price, Length: 10000, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
model = RandomForestRegressor(n_estimators=150, max_depth=3)

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(max_depth=3, n_estimators=150)

# %%
Y_pred = model.predict(X_test)

# %%
Y_pred
# Out:
# array([258.97698955, 249.94935915, 257.32852742, ..., 257.38945927,
#        257.55142067, 256.14897024], shape=(2000,))

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
print(f"MSE: {mean_squared_error(Y_test, Y_pred)}")
print(f"MAE: {mean_absolute_error(Y_test, Y_pred)}")
print(f"R2 score: {r2_score(Y_test, Y_pred)}")
# Out:
# MSE: 17937.66594155552
# MAE: 111.69961857609347
# R2 score: -0.0013032767020333402

# %% [markdown]
# MSE = sum [(y_true - y_pred)^2] / N
# <br>
# MAE = sum [|y_true - y_pred|] / N

# %%
price_results = pd.DataFrame({"actual": Y_test, "pred": Y_pred})

# %%
price_results
# Out:
#        actual        pred
# 1537  420.230  258.976990
# 1892  385.630  249.949359
# 9661   44.100  257.328527
# 1544  265.170  250.469721
# 7707  167.730  250.061182
# ...       ...         ...
# 5886   16.800  256.030388
# 8146  301.374  268.749620
# 8104  160.850  257.389459
# 7442  124.350  257.551421
# 3879   61.230  256.148970
#
# [2000 rows x 2 columns]

# %%
plt.hist(price_results.actual, label='actual')
plt.hist(price_results.pred, label='predicted')
plt.legend()
plt.show()

# %% [markdown]
# ## Feature Importance Analysis

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.bar(np.arange(0, len(model.feature_importances_)),model.feature_importances_)
plt.xticks(np.arange(0, len(model.feature_importances_)), model.feature_names_in_ , rotation=90)
plt.show()
